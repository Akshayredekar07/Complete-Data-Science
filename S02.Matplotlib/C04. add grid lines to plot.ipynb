# %% [markdown]
# - We can add grid lines to the plot. For this we have to use grid() function.
# `plt.grid()`

# %% [markdown]
# import matplotlib.pyplot as plt
# help(plt.grid)
# Help on function grid in module matplotlib.pyplot:
# ```python
# grid(b=None, which='major', axis='both', **kwargs)
#     Configure the grid lines.
# ```
# - plt.grid() ==> on ==> grid lines are visible
# - plt.grid() ==> off ==> grid lines are invisible

# %% [markdown]
# ### Note
# - If b is None and there are no kwargs, this toggles the visibility of the lines.
# - default value for b is None

# %% [markdown]
# ### Various Cases of `plt.grid()` Function Usage
#
# **Case 1**:
# ```python
# plt.grid()
# ```
# - Grid lines will be visible.
#
# **Case 2**:
# ```python
# plt.grid()
# plt.grid()
# ```
# - Grid lines won't be visible (toggling off after the second call).
#
# **Case 3**:
# ```python
# plt.grid()
# plt.grid(color='g')
# ```
# - Grid lines are visible (because keyword arguments like `color` are provided).
#
# **Case 4**:
# ```python
# plt.grid(b=True)
# ```
# - Grid lines are visible (explicitly enabling the grid).
#
# **Case 5**:
# ```python
# plt.grid(b=False)
# ```
# - Grid lines are invisible (explicitly disabling the grid).

# %%
# case-1: grid lines are visible 
import matplotlib.pyplot as plt 
import numpy as np 
a = np.array([10,20,30,40,50]) 
plt.plot(a,a,'o-r') 
plt.grid() 
plt.show()

# %%
# case-2: grid lines are not visible 
import matplotlib.pyplot as plt 
import numpy as np 
a = np.array([10,20,30,40,50]) 
plt.plot(a,a,'o-r') 
plt.grid() 
plt.grid() 
plt.show()

# %%
#case-3: if keyword arguments are given then grid lines are visible 
import matplotlib.pyplot as plt 
import numpy as np 
a = np.array([10,20,30,40,50]) 
plt.plot(a,a,'o-r') 
plt.grid(color='g') 
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

a = np.array([10, 20, 30, 40, 50])
plt.plot(a, a, 'o-r')
plt.grid(visible=True)
plt.show()

# %%
# case-5: plt.grid(b=False) ==> gridlines are not visible 
import matplotlib.pyplot as plt 
import numpy as np 
a = np.array([10,20,30,40,50]) 
plt.plot(a,a,'o-r') 
plt.grid(visible=False) 
plt.show()

# %% [markdown]
# which property
#
# - default is major
# - There are major grid lines and minor grid lines are present
# - which property will decides which grid lines are going to be displayed
# - The allowed values are
#      `which : {'major', 'minor', 'both'}` ==> The default value is major.

# %%
a = np.array([10,20,30,40,50]) 
plt.plot(a,a,'o-r') 
plt.grid(which='both') 
plt.show()

# %% [markdown]
# ### Note
# - To show the minor gridlines we have activate the minorticks_on.
# - Displaying minor ticks may reduce performance; you may turn them off
# using minorticks_off() if drawing speed is a problem.
# - minorticks_on()
# - Display minor ticks on the axes.

# %%
a = np.array([10,20,30,40,50]) 
plt.plot(a,a,'o-r') 
plt.minorticks_on() 
plt.grid(which='both') 
plt.show()

# %% [markdown]
# ### Difference between major and minor grid lines:

# %%
a = np.array([10,20,30,40,50]) 
plt.plot(a,a,'o-r',lw=7,markersize=10,mfc='yellow') 
plt.grid(color='red',lw=3) 
plt.minorticks_on() 
plt.grid(which='minor',color='g') 
plt.show()

# %% [markdown]
# ### axis property
# - Along which axis, grid lines have to display
#      `axis : {'both', 'x', 'y'}` ==> default value: both

# %%
# y-axis 
import matplotlib.pyplot as plt 
import numpy as np 
a = np.array([10,20,30,40,50]) 
plt.plot(a,a,'o-r',lw=7,markersize=10,mfc='yellow') 
plt.grid(axis='y') 
plt.show()

# %%
# y-axis 
import matplotlib.pyplot as plt 
import numpy as np 
a = np.array([10,20,30,40,50]) 
plt.plot(a,a,'o-r',lw=7,markersize=10,mfc='yellow') 
plt.grid(axis='x') 
plt.show()

# %% [markdown]
# ### Passing other keyword arguments
# ### Note:
# - We can use several keyword arguments also.
#     `plt.grid(color='g',lw=2,linestyle=':')`

# %%
a = np.array([10,20,30,40,50]) 
plt.plot(a,a,'o-r',lw=7,markersize=10,mfc='yellow') 
plt.grid(color='g',lw=2,linestyle=':') 
plt.show()
